# %% [markdown]
# <a href="https://colab.research.google.com/github/DmitriyPanfilov/homework_10/blob/main/Task_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import random

lst = ['robot'] * 10

lst += ['human'] * 10

random.shuffle(lst)

data = pd.DataFrame({'whoAmI':lst})

data.head()
# Out:
#   whoAmI
# 0  human
# 1  robot
# 2  robot
# 3  human
# 4  human

# %%
data
# Out:
#    whoAmI
# 0   human
# 1   robot
# 2   robot
# 3   human
# 4   human
# 5   robot
# 6   robot
# 7   human
# 8   robot
# 9   human
# 10  human
# 11  robot
# 12  robot
# 13  robot
# 14  robot
# 15  robot
# 16  human
# 17  human
# 18  human
# 19  human

# %%
data.loc[data['whoAmI'] == 'human', 'human'] = '1'

# %%
data.loc[data['whoAmI'] != 'human', 'human'] = '0'

# %%
data.drop(columns='whoAmI')
# Out:
#    human
# 0      1
# 1      0
# 2      0
# 3      1
# 4      1
# 5      0
# 6      0
# 7      1
# 8      0
# 9      1
# 10     1
# 11     0
# 12     0
# 13     0
# 14     0
# 15     0
# 16     1
# 17     1
# 18     1
# 19     1
